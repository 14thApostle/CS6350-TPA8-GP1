# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import xml.dom.minidom
from xml.dom.minidom import parse
from PIL import Image
from torchvision import transforms
from torchvision import transforms
import os
from os.path import join
import matplotlib.pyplot as plt
from torchinfo import summary

from networks.GCResNet import *

# %%
folder_path = "./"
option_file = parse(os.path.join(folder_path,r'options.xml'))
options = option_file.getElementsByTagName("options")[0]
batch_size = 64

model1 = Deblur_model(options)

# %%
print(model1)
# Out:
# Deblur_model(
#   (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (downsample_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (downsample_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (downsample_graph): Conv2d(128, 128, kernel_size=(3, 3), stride=(10, 10), padding=(1, 1))
#   (graph_convhead): GraphConvolution (1 -> 32)
#   (graph_convtail): GraphConvolution (32 -> 1)
#   (upsample_graph): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(10, 10), padding=(1, 1), output_padding=(9, 9))
#   (upsample_2): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (upsample_1): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (relu): LeakyReLU(negative_slope=0.2)
#   (head): Sequential(
# ...

# %%
from networks.GFN_4x import Net, Net2

# %%
model2 = Net2()
print(model2)
summary(model2, (1, 3, 64, 64), gated=True, isTest = True)
# Out:
# Net2(
#   (deblurMoudle): Sequential(
#     (0): _Deblur_model(
#       (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#       (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#       (downsample_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (downsample_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (downsample_graph): Conv2d(128, 128, kernel_size=(3, 3), stride=(10, 10), padding=(1, 1))
#       (graph_convhead): GraphConvolution (1 -> 32)
#       (graph_convtail): GraphConvolution (32 -> 1)
#       (upsample_graph): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(8, 8), padding=(1, 1), output_padding=(7, 7))
#       (upsample_2): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (upsample_1): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
# ...

# %%
model3 = Net()
print(model3)
summary(model3, (1, 3, 64, 64), gated=True, isTest = True)
# Out:
# Net(
#   (deblurMoudle): Sequential(
#     (0): _DeblurringMoudle(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (relu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (resBlock1): Sequential(
#         (0): _ResBLockDB(
#           (layers): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (1): _ResBLockDB(
#           (layers): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#         (2): _ResBLockDB(
#           (layers): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...
